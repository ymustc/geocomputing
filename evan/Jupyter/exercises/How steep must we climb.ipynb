# %% [markdown]
# # How steep must we climb?

# %% [markdown]
# in this exercise less compute the slope (gradient) of the surface topography map

# %%
import numpy as np
z = np.load('../data/topography.npy')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(z)

# %% [markdown]
# define a function called gradient that computs the local steepness of the surface

# %%
def gradient(z):
    """
    Your code goes here
    """
    #
    #
    #
    return

# %% [markdown]
# try out differnt display styles:
#
# - show it as an image,
#
# - as a surface,
#
# - as a series of lines,
#
# - with different colormaps
#
# - etc.
